# %%
from pyspark.sql import SparkSession
from delta.tables import DeltaTable

# %%
spark: SparkSession = (
    SparkSession.builder.master("local[*]")
    .appName("Henry-NxtGen-Framework")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate()
)

# %%
from data_dallion_framework.BronzeScripts import PerformBronze
from data_dallion_framework.SilverScripts import SilverLayerProcess
from data_dallion_framework.GoldScripts import PerformGoldLayerProcess

# %%
PerformBronze.PerformBronze(spark=spark, process_id=1000).start_extraction()

# %%
SilverLayerProcess.SilverLayerProcess(spark=spark,process_id=1000)

# %%
PerformGoldLayerProcess.GoldLayerProcess(spark=spark,process_id=1000)

# %%
select_columns = [
    'track_id',
    'artist_id',
    'others'
]

# %%
df = spark.read.format('delta').load('publish/ods/YOUTUBE/JEON_SOMI/INDIA_CITY_GOLD')

# %%
gp = ['artist_name','report_date']

# %%
df[gp]
