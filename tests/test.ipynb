# %%
from pyspark.sql import SparkSession

# %%
spark: SparkSession = (
    SparkSession.builder.master("local[*]")
    .appName("Henry-NxtGen-Framework")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .getOrCreate()
)

# %%
from data_dallion_framework.BronzeScripts import PerformBronze
from data_dallion_framework.SilverScripts import SilverLayerProcess

# %%
PerformBronze.PerformBronze(spark=spark, process_id=2000).start_extraction()

# %%
SilverLayerProcess.SilverLayerProcess(spark=spark,process_id=2000)

# %%
df = spark.read.format("delta").load("compute/landing/YOUTUBE/JEON_SOMI/INDIA_HYDERABAD")

# %%
df.show()

# %%
after_dqm = spark.read.format("delta").load("compute/staging/YOUTUBE/JEON_SOMI/INDIA_HYDERABAD")

# %%
after_dqm.show()
