# %%
from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env file

# %%
from data_dallion_framework.Common.OrchestrationProcess import OrchestrationProcess

# %%
with OrchestrationProcess() as op:
    op.get_ctl_api_connection_details(dataset_id=2000)
